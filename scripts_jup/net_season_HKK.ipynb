# %%
import numpy as np
from radial_constrained_cluster_copy import *
import matplotlib.pyplot as plt
import matplotlib
import random
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import xarray as xr
from xarray import Dataset
from eofs.multivariate.standard import MultivariateEof
from shapely.geometry import mapping
from sklearn.cluster import KMeans
from scipy import signal
from obspy.signal.tf_misfit import cwt
import pymannkendall as mk
from tqdm import tqdm
from time import sleep

import dask
dask.config.set(scheduler="synchronous")

from tensorflow.keras import layers, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

matplotlib.rc('font', **font)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
region_division = gpd.read_file('~/work/jacopo/DATA/regions/region_division.shp', crs="epsg:4326")
#region_division = world

himalaya = Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])
himalaya = gpd.GeoDataFrame({'geometry': [Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])]})
hkk = Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])
hkk = gpd.GeoDataFrame({'geometry': [Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])]})
# Out:
# 2022-10-14 12:08:19.313573: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-14 12:08:19.471382: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-14 12:08:19.471403: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-14 12:08:19.498855: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-14 12:08:20.075278: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-14 12:08:20.075382: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-14 12:08:20.075389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
n_eof_comp = 3
fields = ['tp']
lat_boundaries = [5,40]
lon_boundaries = [65,100]

#d = xr.open_mfdataset("/archive/paolo/cmip6/CMIP6/model-output/EC-Earth-Consortium/EC-Earth3/historical/atmos/day/r1i1p1f1/pr/*.nc").drop(['time_bnds','lat_bnds','lon_bnds']).rename(pr = 'tp')*24000
#a = xr.open_mfdataset("/home/paolo/archive/cmip6/CMIP6/model-output/EC-Earth-Consortium/EC-Earth3/ssp585/atmos/day/r1i1p1f1/pr/*.nc").drop(['time_bnds','lat_bnds','lon_bnds']).rename(pr = 'tp')*24000
#dataset = xr.concat([d,a],'time')
#dataset = dataset.sortby(['lat']).sortby(['lon'])
#dataset = dataset.sel(lat=slice(np.min(lat_boundaries),np.max(lat_boundaries)), lon=slice(np.min(lon_boundaries),np.max(lon_boundaries))).load()

#dataset = xr.open_dataset("~/work/jacopo/DATA/ERA5_prec_day_INDIA.nc").drop("time_bnds").rename(tp = 'tp')*24000

dataset = xr.open_dataset("~/work/jacopo/DATA/APHRODITE_1951_2007_daily_INDIA.nc").drop('rstn').fillna(0).rename( latitude='lat', longitude='lon', precip='tp')

dataset = dataset.resample(time='1D').first()
dataset = dataset.sel(time=~((dataset['time.month'] == 2) & (dataset['time.day'] == 29)))
dataset = dataset.rolling(time=30, center=True).mean().fillna(0)

# %%
to_see = 'hkk'

if to_see == 'him':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True)
    data = data.rio.clip(himalaya.geometry.apply(mapping), himalaya.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
elif to_see == 'hkk':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True) 
    data = dataset.rio.clip(hkk.geometry.apply(mapping), hkk.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
else:
    print('none')

# %%
###################################################################
data_to_train = data.sel(time=slice('1980','2000'))
data_to_train_doy = data_to_train.groupby('time.dayofyear').mean()
data_to_train_doy = data_to_train_doy.sel(dayofyear=~(data_to_train_doy['dayofyear'] == 50))
data_to_train = data_to_train.drop('spatial_ref')
###################################################################

# %%
# Creating base for seasonal division
seasons_names = ['winter','spring','summer','autumn']

to_eof = []
for i in fields:
    supp = getattr(data_to_train_doy,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())

solver = MultivariateEof(to_eof)
pc = solver.pcs(npcs = n_eof_comp)

len_consistancy_check = True
min_len = 20
learning_rate = 1
scheduling_factor = 1.1
l_r_scheduler = True
n_iter = 1000
n_seas = 4

model = Radially_Constrained_Cluster(pc, n_seas, n_iter, 
                                learning_rate, l_r_scheduler, scheduling_factor, 
                                len_consistancy_check, min_len)

model.fit()
prediction = model.get_prediction()


plt.figure(figsize = (15,6))
plt.plot(model.error_story)
plt.grid()
plt.xlabel('N° iterations')
plt.ylabel('Within-Cluster Sum of Square')

cc = model.get_centroids()
print(f'Final error: {model.get_final_error()}')
print(f'Breakpoints: {model.breakpoints}')

fig, ax = plt.subplots(figsize = (15,6))
scatter = ax.scatter(range(np.size(pc, axis=0)), data_to_train_doy.tp.mean(['lat','lon']), c = prediction)
legend1 = ax.legend(handles=scatter.legend_elements()[0], labels=seasons_names)
ax.set_title('Seasonal clustering')
ax.add_artist(legend1)
ax.grid()
ax.set_xlabel('julian day')
ax.set_ylabel('Tp [mm/day]')
ax.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])


fig, axs = plt.subplots(1,2, figsize = (18,6), sharey = True, sharex=True)
axs[0].scatter(pc[:,0],pc[:,1], c = prediction )
for i in range(n_seas):
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
axs[0].grid()
axs[0].set_xlabel('PC 1')
axs[0].set_ylabel('PC 2')

axs[1].scatter(pc[:,0],pc[:,2], c = prediction)
axs[1].grid()
axs[1].set_xlabel('PC 1')
axs[1].set_ylabel('PC 3')
# Out:
# Final error: 23263.436145365897
# Breakpoints: [121 183 252 361]
# Text(0, 0.5, 'PC 3')

# %%
to_eof = []
for i in fields:
    supp = getattr(data_to_train,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())


pc_train = solver.projectField(to_eof)
pc_train = pc_train[:,0:n_eof_comp]

y_train = np.squeeze(np.array([prediction]*21).reshape((365*21,1)))

# %%
np.shape(pc_train)
# Out:
# (7665, 3)

# %%
input = layers.Input(shape=(n_eof_comp))

# Encoder
x = layers.Dense(3, activation='relu')(input)
x = layers.Dense(4, activation='relu')(x)
x = layers.Dense(5, activation='relu')(x)
x = layers.Dense(n_seas, activation='softmax')(x)


# Autoencoder
lstm_net = Model(input, x)
lstm_net.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics='accuracy')
lstm_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 3)                 12
#
#  dense_1 (Dense)             (None, 4)                 16
#
#  dense_2 (Dense)             (None, 5)                 25
#
#  dense_3 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# _________________________________________________________________
# 2022-10-14 12:08:59.416999: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-14 12:08:59.417043: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-14 12:08:59.417075: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (wilma): /proc/driver/nvidia/version does not exist
# 2022-10-14 12:08:59.417503: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_history = lstm_net.fit(
    x=pc_train,
    y=y_train,
    epochs=200,
    batch_size=128,
#    validation_data = pc_vale,
    validation_split = 0.2,
    shuffle=True
)

plt.figure()
plt.plot(model_history.history["loss"], label='loss')
plt.plot(model_history.history["val_loss"], label='validation loss')
plt.title("Loss vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)


plt.figure()
plt.plot(model_history.history["accuracy"], label='accuracy')
plt.plot(model_history.history["val_accuracy"], label='validation accuracy')
plt.title("Accuracy vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
# Out:
# Epoch 1/200
# 48/48 [==============================] - 1s 9ms/step - loss: 1.5583 - accuracy: 0.2663 - val_loss: 1.4226 - val_accuracy: 0.4070
# Epoch 2/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.2413 - accuracy: 0.4318 - val_loss: 1.2760 - val_accuracy: 0.4573
# Epoch 3/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.1644 - accuracy: 0.4640 - val_loss: 1.1913 - val_accuracy: 0.4684
# Epoch 4/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.1244 - accuracy: 0.5005 - val_loss: 1.1350 - val_accuracy: 0.4716
# Epoch 5/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.0893 - accuracy: 0.5282 - val_loss: 1.0827 - val_accuracy: 0.5029
# Epoch 6/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.0510 - accuracy: 0.5442 - val_loss: 1.0247 - val_accuracy: 0.5708
# Epoch 7/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.0124 - accuracy: 0.5656 - val_loss: 0.9619 - val_accuracy: 0.6080
# Epoch 8/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9699 - accuracy: 0.5881 - val_loss: 0.9105 - val_accuracy: 0.6334
# Epoch 9/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9333 - accuracy: 0.6091 - val_loss: 0.8709 - val_accuracy: 0.6654
# Epoch 10/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9072 - accuracy: 0.6285 - val_loss: 0.8385 - val_accuracy: 0.6699
# Epoch 11/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8849 - accuracy: 0.6381 - val_loss: 0.8220 - val_accuracy: 0.6725
# Epoch 12/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8653 - accuracy: 0.6508 - val_loss: 0.7967 - val_accuracy: 0.6784
# Epoch 13/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8508 - accuracy: 0.6564 - val_loss: 0.7858 - val_accuracy: 0.6778
# Epoch 14/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8389 - accuracy: 0.6632 - val_loss: 0.7779 - val_accuracy: 0.6693
# Epoch 15/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8278 - accuracy: 0.6740 - val_loss: 0.7617 - val_accuracy: 0.6732
# Epoch 16/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8161 - accuracy: 0.6797 - val_loss: 0.7512 - val_accuracy: 0.6719
# Epoch 17/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8044 - accuracy: 0.6854 - val_loss: 0.7436 - val_accuracy: 0.6791
# Epoch 18/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7957 - accuracy: 0.6954 - val_loss: 0.7309 - val_accuracy: 0.6830
# Epoch 19/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7863 - accuracy: 0.6994 - val_loss: 0.7147 - val_accuracy: 0.6934
# Epoch 20/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7774 - accuracy: 0.7016 - val_loss: 0.7103 - val_accuracy: 0.6980
# Epoch 21/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7682 - accuracy: 0.7032 - val_loss: 0.7044 - val_accuracy: 0.7038
# Epoch 22/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7598 - accuracy: 0.7071 - val_loss: 0.7000 - val_accuracy: 0.6967
# Epoch 23/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7526 - accuracy: 0.7091 - val_loss: 0.6941 - val_accuracy: 0.7006
# Epoch 24/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7471 - accuracy: 0.7107 - val_loss: 0.6930 - val_accuracy: 0.7025
# Epoch 25/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7423 - accuracy: 0.7122 - val_loss: 0.6925 - val_accuracy: 0.6999
# Epoch 26/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7362 - accuracy: 0.7135 - val_loss: 0.6855 - val_accuracy: 0.7019
# Epoch 27/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7318 - accuracy: 0.7159 - val_loss: 0.6866 - val_accuracy: 0.7130
# Epoch 28/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7274 - accuracy: 0.7187 - val_loss: 0.6836 - val_accuracy: 0.7149
# Epoch 29/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7234 - accuracy: 0.7184 - val_loss: 0.6765 - val_accuracy: 0.7019
# Epoch 30/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7213 - accuracy: 0.7195 - val_loss: 0.6729 - val_accuracy: 0.7117
# Epoch 31/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7168 - accuracy: 0.7202 - val_loss: 0.6772 - val_accuracy: 0.7097
# Epoch 32/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7150 - accuracy: 0.7195 - val_loss: 0.6766 - val_accuracy: 0.7032
# Epoch 33/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7131 - accuracy: 0.7203 - val_loss: 0.6728 - val_accuracy: 0.7143
# Epoch 34/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7100 - accuracy: 0.7203 - val_loss: 0.6750 - val_accuracy: 0.7078
# Epoch 35/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7082 - accuracy: 0.7211 - val_loss: 0.6653 - val_accuracy: 0.7097
# Epoch 36/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7060 - accuracy: 0.7239 - val_loss: 0.6617 - val_accuracy: 0.7169
# Epoch 37/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7046 - accuracy: 0.7226 - val_loss: 0.6594 - val_accuracy: 0.7156
# Epoch 38/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7027 - accuracy: 0.7237 - val_loss: 0.6677 - val_accuracy: 0.7123
# Epoch 39/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7017 - accuracy: 0.7180 - val_loss: 0.6603 - val_accuracy: 0.7136
# Epoch 40/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6998 - accuracy: 0.7210 - val_loss: 0.6646 - val_accuracy: 0.7143
# Epoch 41/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6993 - accuracy: 0.7200 - val_loss: 0.6588 - val_accuracy: 0.7065
# Epoch 42/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6979 - accuracy: 0.7193 - val_loss: 0.6589 - val_accuracy: 0.7123
# Epoch 43/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6958 - accuracy: 0.7211 - val_loss: 0.6570 - val_accuracy: 0.7032
# Epoch 44/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6950 - accuracy: 0.7193 - val_loss: 0.6527 - val_accuracy: 0.7169
# Epoch 45/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6947 - accuracy: 0.7215 - val_loss: 0.6542 - val_accuracy: 0.7019
# Epoch 46/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.7205 - val_loss: 0.6557 - val_accuracy: 0.7045
# Epoch 47/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.7229 - val_loss: 0.6514 - val_accuracy: 0.7045
# Epoch 48/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.7211 - val_loss: 0.6494 - val_accuracy: 0.7130
# Epoch 49/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.7203 - val_loss: 0.6502 - val_accuracy: 0.7038
# Epoch 50/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6897 - accuracy: 0.7211 - val_loss: 0.6472 - val_accuracy: 0.7195
# Epoch 51/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.7234 - val_loss: 0.6513 - val_accuracy: 0.7175
# Epoch 52/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.7234 - val_loss: 0.6491 - val_accuracy: 0.7052
# Epoch 53/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.7189 - val_loss: 0.6461 - val_accuracy: 0.7175
# Epoch 54/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6843 - accuracy: 0.7239 - val_loss: 0.6518 - val_accuracy: 0.7052
# Epoch 55/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.7226 - val_loss: 0.6483 - val_accuracy: 0.7293
# Epoch 56/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.7233 - val_loss: 0.6429 - val_accuracy: 0.7234
# Epoch 57/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6826 - accuracy: 0.7213 - val_loss: 0.6456 - val_accuracy: 0.7247
# Epoch 58/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.7220 - val_loss: 0.6432 - val_accuracy: 0.7286
# Epoch 59/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6808 - accuracy: 0.7250 - val_loss: 0.6451 - val_accuracy: 0.7306
# Epoch 60/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.7233 - val_loss: 0.6464 - val_accuracy: 0.7215
# Epoch 61/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.7228 - val_loss: 0.6448 - val_accuracy: 0.7254
# Epoch 62/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.7249 - val_loss: 0.6431 - val_accuracy: 0.7312
# Epoch 63/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6784 - accuracy: 0.7239 - val_loss: 0.6427 - val_accuracy: 0.7254
# Epoch 64/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.7241 - val_loss: 0.6410 - val_accuracy: 0.7293
# Epoch 65/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.7223 - val_loss: 0.6498 - val_accuracy: 0.7130
# Epoch 66/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.7244 - val_loss: 0.6470 - val_accuracy: 0.7293
# Epoch 67/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.7246 - val_loss: 0.6535 - val_accuracy: 0.7215
# Epoch 68/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.7228 - val_loss: 0.6440 - val_accuracy: 0.7332
# Epoch 69/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.7267 - val_loss: 0.6421 - val_accuracy: 0.7306
# Epoch 70/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6751 - accuracy: 0.7242 - val_loss: 0.6402 - val_accuracy: 0.7306
# Epoch 71/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.7255 - val_loss: 0.6401 - val_accuracy: 0.7312
# Epoch 72/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6746 - accuracy: 0.7236 - val_loss: 0.6458 - val_accuracy: 0.7319
# Epoch 73/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6758 - accuracy: 0.7252 - val_loss: 0.6462 - val_accuracy: 0.7260
# Epoch 74/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6746 - accuracy: 0.7239 - val_loss: 0.6418 - val_accuracy: 0.7312
# Epoch 75/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.7246 - val_loss: 0.6488 - val_accuracy: 0.7273
# Epoch 76/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6749 - accuracy: 0.7229 - val_loss: 0.6485 - val_accuracy: 0.7293
# Epoch 77/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.7239 - val_loss: 0.6487 - val_accuracy: 0.7306
# Epoch 78/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6728 - accuracy: 0.7267 - val_loss: 0.6388 - val_accuracy: 0.7456
# Epoch 79/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6735 - accuracy: 0.7272 - val_loss: 0.6449 - val_accuracy: 0.7299
# Epoch 80/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6728 - accuracy: 0.7252 - val_loss: 0.6468 - val_accuracy: 0.7339
# Epoch 81/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.7242 - val_loss: 0.6447 - val_accuracy: 0.7352
# Epoch 82/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.7262 - val_loss: 0.6418 - val_accuracy: 0.7378
# Epoch 83/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6716 - accuracy: 0.7272 - val_loss: 0.6480 - val_accuracy: 0.7345
# Epoch 84/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6718 - accuracy: 0.7278 - val_loss: 0.6454 - val_accuracy: 0.7391
# Epoch 85/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.7273 - val_loss: 0.6496 - val_accuracy: 0.7339
# Epoch 86/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.7239 - val_loss: 0.6490 - val_accuracy: 0.7286
# Epoch 87/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.7260 - val_loss: 0.6490 - val_accuracy: 0.7319
# Epoch 88/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.7273 - val_loss: 0.6419 - val_accuracy: 0.7365
# Epoch 89/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6711 - accuracy: 0.7260 - val_loss: 0.6422 - val_accuracy: 0.7404
# Epoch 90/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6718 - accuracy: 0.7255 - val_loss: 0.6417 - val_accuracy: 0.7397
# Epoch 91/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.7272 - val_loss: 0.6447 - val_accuracy: 0.7332
# Epoch 92/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.7249 - val_loss: 0.6413 - val_accuracy: 0.7417
# Epoch 93/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.7259 - val_loss: 0.6456 - val_accuracy: 0.7404
# Epoch 94/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.7257 - val_loss: 0.6416 - val_accuracy: 0.7404
# Epoch 95/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.7260 - val_loss: 0.6420 - val_accuracy: 0.7345
# Epoch 96/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6720 - accuracy: 0.7250 - val_loss: 0.6472 - val_accuracy: 0.7326
# Epoch 97/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.7257 - val_loss: 0.6505 - val_accuracy: 0.7423
# Epoch 98/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6702 - accuracy: 0.7275 - val_loss: 0.6457 - val_accuracy: 0.7326
# Epoch 99/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.7265 - val_loss: 0.6435 - val_accuracy: 0.7371
# Epoch 100/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6695 - accuracy: 0.7249 - val_loss: 0.6477 - val_accuracy: 0.7378
# Epoch 101/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.7268 - val_loss: 0.6464 - val_accuracy: 0.7430
# Epoch 102/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.7267 - val_loss: 0.6511 - val_accuracy: 0.7430
# Epoch 103/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.7265 - val_loss: 0.6505 - val_accuracy: 0.7312
# Epoch 104/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.7267 - val_loss: 0.6444 - val_accuracy: 0.7417
# Epoch 105/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.7252 - val_loss: 0.6449 - val_accuracy: 0.7404
# Epoch 106/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7249 - val_loss: 0.6450 - val_accuracy: 0.7449
# Epoch 107/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6692 - accuracy: 0.7231 - val_loss: 0.6410 - val_accuracy: 0.7436
# Epoch 108/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7231 - val_loss: 0.6460 - val_accuracy: 0.7397
# Epoch 109/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.7249 - val_loss: 0.6495 - val_accuracy: 0.7404
# Epoch 110/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.7249 - val_loss: 0.6429 - val_accuracy: 0.7436
# Epoch 111/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.7255 - val_loss: 0.6475 - val_accuracy: 0.7462
# Epoch 112/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6693 - accuracy: 0.7242 - val_loss: 0.6450 - val_accuracy: 0.7449
# Epoch 113/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.7242 - val_loss: 0.6482 - val_accuracy: 0.7417
# Epoch 114/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.7260 - val_loss: 0.6471 - val_accuracy: 0.7417
# Epoch 115/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.7283 - val_loss: 0.6496 - val_accuracy: 0.7449
# Epoch 116/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7259 - val_loss: 0.6443 - val_accuracy: 0.7397
# Epoch 117/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6683 - accuracy: 0.7280 - val_loss: 0.6545 - val_accuracy: 0.7404
# Epoch 118/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6697 - accuracy: 0.7244 - val_loss: 0.6429 - val_accuracy: 0.7397
# Epoch 119/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7273 - val_loss: 0.6487 - val_accuracy: 0.7430
# Epoch 120/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6686 - accuracy: 0.7254 - val_loss: 0.6429 - val_accuracy: 0.7423
# Epoch 121/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6692 - accuracy: 0.7259 - val_loss: 0.6465 - val_accuracy: 0.7410
# Epoch 122/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.7259 - val_loss: 0.6490 - val_accuracy: 0.7358
# Epoch 123/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.7233 - val_loss: 0.6513 - val_accuracy: 0.7391
# Epoch 124/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.7259 - val_loss: 0.6434 - val_accuracy: 0.7423
# Epoch 125/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.7237 - val_loss: 0.6453 - val_accuracy: 0.7469
# Epoch 126/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7236 - val_loss: 0.6500 - val_accuracy: 0.7397
# Epoch 127/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7242 - val_loss: 0.6461 - val_accuracy: 0.7410
# Epoch 128/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7249 - val_loss: 0.6487 - val_accuracy: 0.7352
# Epoch 129/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7249 - val_loss: 0.6432 - val_accuracy: 0.7417
# Epoch 130/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6680 - accuracy: 0.7254 - val_loss: 0.6445 - val_accuracy: 0.7443
# Epoch 131/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6677 - accuracy: 0.7231 - val_loss: 0.6472 - val_accuracy: 0.7417
# Epoch 132/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.7249 - val_loss: 0.6441 - val_accuracy: 0.7430
# Epoch 133/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.7280 - val_loss: 0.6468 - val_accuracy: 0.7358
# Epoch 134/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6680 - accuracy: 0.7262 - val_loss: 0.6505 - val_accuracy: 0.7495
# Epoch 135/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7255 - val_loss: 0.6447 - val_accuracy: 0.7443
# Epoch 136/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.7252 - val_loss: 0.6458 - val_accuracy: 0.7476
# Epoch 137/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6680 - accuracy: 0.7250 - val_loss: 0.6481 - val_accuracy: 0.7397
# Epoch 138/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.7259 - val_loss: 0.6433 - val_accuracy: 0.7436
# Epoch 139/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.7241 - val_loss: 0.6404 - val_accuracy: 0.7456
# Epoch 140/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.7239 - val_loss: 0.6433 - val_accuracy: 0.7423
# Epoch 141/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.7239 - val_loss: 0.6485 - val_accuracy: 0.7352
# Epoch 142/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.7268 - val_loss: 0.6470 - val_accuracy: 0.7423
# Epoch 143/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7226 - val_loss: 0.6498 - val_accuracy: 0.7423
# Epoch 144/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.7264 - val_loss: 0.6533 - val_accuracy: 0.7345
# Epoch 145/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.7267 - val_loss: 0.6469 - val_accuracy: 0.7371
# Epoch 146/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.7268 - val_loss: 0.6448 - val_accuracy: 0.7417
# Epoch 147/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.7259 - val_loss: 0.6433 - val_accuracy: 0.7423
# Epoch 148/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6677 - accuracy: 0.7262 - val_loss: 0.6412 - val_accuracy: 0.7449
# Epoch 149/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6679 - accuracy: 0.7236 - val_loss: 0.6512 - val_accuracy: 0.7378
# Epoch 150/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.7249 - val_loss: 0.6481 - val_accuracy: 0.7378
# Epoch 151/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.7221 - val_loss: 0.6503 - val_accuracy: 0.7410
# Epoch 152/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6667 - accuracy: 0.7249 - val_loss: 0.6514 - val_accuracy: 0.7326
# Epoch 153/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7250 - val_loss: 0.6518 - val_accuracy: 0.7397
# Epoch 154/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.7257 - val_loss: 0.6516 - val_accuracy: 0.7443
# Epoch 155/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.7244 - val_loss: 0.6463 - val_accuracy: 0.7430
# Epoch 156/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.7254 - val_loss: 0.6496 - val_accuracy: 0.7502
# Epoch 157/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.7254 - val_loss: 0.6523 - val_accuracy: 0.7339
# Epoch 158/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6674 - accuracy: 0.7267 - val_loss: 0.6543 - val_accuracy: 0.7456
# Epoch 159/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.7259 - val_loss: 0.6533 - val_accuracy: 0.7508
# Epoch 160/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7247 - val_loss: 0.6496 - val_accuracy: 0.7423
# Epoch 161/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6673 - accuracy: 0.7281 - val_loss: 0.6464 - val_accuracy: 0.7391
# Epoch 162/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6666 - accuracy: 0.7273 - val_loss: 0.6491 - val_accuracy: 0.7443
# Epoch 163/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6670 - accuracy: 0.7280 - val_loss: 0.6499 - val_accuracy: 0.7443
# Epoch 164/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6670 - accuracy: 0.7277 - val_loss: 0.6530 - val_accuracy: 0.7371
# Epoch 165/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.7267 - val_loss: 0.6500 - val_accuracy: 0.7469
# Epoch 166/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6667 - accuracy: 0.7280 - val_loss: 0.6508 - val_accuracy: 0.7449
# Epoch 167/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6659 - accuracy: 0.7259 - val_loss: 0.6546 - val_accuracy: 0.7339
# Epoch 168/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.7286 - val_loss: 0.6531 - val_accuracy: 0.7430
# Epoch 169/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.7281 - val_loss: 0.6501 - val_accuracy: 0.7397
# Epoch 170/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7242 - val_loss: 0.6512 - val_accuracy: 0.7358
# Epoch 171/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.7281 - val_loss: 0.6470 - val_accuracy: 0.7449
# Epoch 172/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.7244 - val_loss: 0.6482 - val_accuracy: 0.7443
# Epoch 173/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6666 - accuracy: 0.7260 - val_loss: 0.6497 - val_accuracy: 0.7449
# Epoch 174/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.7259 - val_loss: 0.6547 - val_accuracy: 0.7332
# Epoch 175/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.7254 - val_loss: 0.6526 - val_accuracy: 0.7449
# Epoch 176/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.7275 - val_loss: 0.6502 - val_accuracy: 0.7410
# Epoch 177/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6670 - accuracy: 0.7268 - val_loss: 0.6504 - val_accuracy: 0.7482
# Epoch 178/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.7242 - val_loss: 0.6487 - val_accuracy: 0.7462
# Epoch 179/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6655 - accuracy: 0.7283 - val_loss: 0.6535 - val_accuracy: 0.7436
# Epoch 180/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.7264 - val_loss: 0.6531 - val_accuracy: 0.7423
# Epoch 181/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6654 - accuracy: 0.7277 - val_loss: 0.6518 - val_accuracy: 0.7469
# Epoch 182/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.7244 - val_loss: 0.6488 - val_accuracy: 0.7443
# Epoch 183/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6650 - accuracy: 0.7242 - val_loss: 0.6541 - val_accuracy: 0.7384
# Epoch 184/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6647 - accuracy: 0.7259 - val_loss: 0.6536 - val_accuracy: 0.7489
# Epoch 185/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6673 - accuracy: 0.7272 - val_loss: 0.6470 - val_accuracy: 0.7462
# Epoch 186/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6654 - accuracy: 0.7242 - val_loss: 0.6456 - val_accuracy: 0.7476
# Epoch 187/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6651 - accuracy: 0.7255 - val_loss: 0.6503 - val_accuracy: 0.7456
# Epoch 188/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.7280 - val_loss: 0.6569 - val_accuracy: 0.7469
# Epoch 189/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6649 - accuracy: 0.7257 - val_loss: 0.6537 - val_accuracy: 0.7436
# Epoch 190/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6646 - accuracy: 0.7236 - val_loss: 0.6545 - val_accuracy: 0.7482
# Epoch 191/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6652 - accuracy: 0.7254 - val_loss: 0.6453 - val_accuracy: 0.7495
# Epoch 192/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.7264 - val_loss: 0.6567 - val_accuracy: 0.7352
# Epoch 193/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.7265 - val_loss: 0.6494 - val_accuracy: 0.7476
# Epoch 194/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6646 - accuracy: 0.7231 - val_loss: 0.6509 - val_accuracy: 0.7482
# Epoch 195/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6642 - accuracy: 0.7255 - val_loss: 0.6534 - val_accuracy: 0.7417
# Epoch 196/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6647 - accuracy: 0.7278 - val_loss: 0.6493 - val_accuracy: 0.7462
# Epoch 197/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6640 - accuracy: 0.7283 - val_loss: 0.6500 - val_accuracy: 0.7462
# Epoch 198/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6645 - accuracy: 0.7268 - val_loss: 0.6491 - val_accuracy: 0.7476
# Epoch 199/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6649 - accuracy: 0.7265 - val_loss: 0.6519 - val_accuracy: 0.7397
# Epoch 200/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6653 - accuracy: 0.7255 - val_loss: 0.6481 - val_accuracy: 0.7469

# %%
p = []
peri = []
s_index = []

for i in tqdm(np.arange(0,40,10)):

    plt.figure(figsize=(15,6))
    sleep(3)
    data_to_test = data.sel(time=slice(str(1970+i),str(1990+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    #pc_test = (pc_test)/pc_test.max(axis=0)
    pred_season = lstm_net.predict(pc_test, verbose = 0)
    p.append(pred_season)

    for i in range(n_seas):

        plt.plot(range(0,len(pred_season)),pred_season[:,i], label=f'{seasons_names[i]}')
    
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
    plt.grid()
    plt.legend()
    plt.ylabel('prob')
    plt.title(f"{data_to_test['time.year'][0].to_numpy()} - {data_to_test['time.year'][-1].to_numpy()}")
    s_index.append(pred_season.argmax(-1))
# Out:
# 100%|██████████| 4/4 [00:15<00:00,  3.88s/it]

# %%
fig, ax = plt.subplots(4,1, figsize=(15,24))

for j in range(len(peri)):

    ax[0].plot(range(0,len(pred_season)),p[j][:,0])
    ax[0].set_title(f'{seasons_names[0]}')
    ax[1].plot(range(0,len(pred_season)),p[j][:,1])
    ax[1].set_title(f'{seasons_names[1]}')
    ax[2].plot(range(0,len(pred_season)),p[j][:,2], label = f'{peri[j][0]} - {peri[j][1]}')
    ax[2].set_title(f'{seasons_names[2]}')
    ax[3].plot(range(0,len(pred_season)),p[j][:,3])
    ax[3].set_title(f'{seasons_names[3]}')

for i in ax:
    i.set_ylabel('prob')
    i.grid()
    i.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])



fig.legend(loc = 'center right')

# %%
p = []
peri = []
s_index = []
s_len = []
s_mean = []
yr = []

for i in tqdm(np.arange(0,40,1)):

    sleep(3)
    data_to_test = data.sel(time=slice(str(1950+i),str(1970+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    l_t = data_to_test_doy.mean(['lat','lon']).tp.to_numpy()
    l_t = l_t[0:365]

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    pred_season = lstm_net.predict(pc_test, verbose=0)
    p.append(pred_season)

    predi = pred_season.argmax(-1)
    
    s_index.append(predi)

    len_seas = np.empty((n_seas,1))
    mean_seas = np.empty((n_seas,1))

    for k in range(n_seas):
        len_seas[k] = np.count_nonzero(predi==k)
        mean_seas[k] = np.mean(l_t[predi==k])

    s_len.append(len_seas)
    s_mean.append(mean_seas)
# Out:
# 100%|██████████| 40/40 [02:34<00:00,  3.87s/it]

# %%
s_len = np.array(s_len)
s_mean = np.array(s_mean)

plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_len[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season length')


plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_mean[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season mean')
# Out:
# Text(0.5, 1.0, 'Season mean')

# %%
pr = np.squeeze(np.array(p))
plt.figure(figsize=(20,5))
ps = np.squeeze(np.array(peri))


for i in range(n_seas):
    plt.figure(figsize=(15,10))
    cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)
    plt.title(seasons_names[i])
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
# Out:
# /tmp/ipykernel_1207605/2417149041.py:8: UserWarning: The following kwargs were not used by contour: 'vamx'
#   cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)

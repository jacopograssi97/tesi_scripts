# %%
from basic_op_jup import *
from I_O_manage import *
import json
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as mpc
import numpy as np
from cdo import Cdo
import bottleneck as bk
import pandas as pd
cdo=Cdo()

# %%
# Opening JSON file
dataset = input_interface('I_O.json')

# %%
dataset

# %%
getattr(dataset,'ERA5').mean('time').plot()

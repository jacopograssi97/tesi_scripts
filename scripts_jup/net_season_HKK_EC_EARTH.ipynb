# %%
import numpy as np
from radial_constrained_cluster_copy import *
import matplotlib.pyplot as plt
import matplotlib
import random
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import xarray as xr
from xarray import Dataset
from eofs.multivariate.standard import MultivariateEof
from shapely.geometry import mapping
from sklearn.cluster import KMeans
from scipy import signal
from obspy.signal.tf_misfit import cwt
import pymannkendall as mk
from tqdm import tqdm
from time import sleep

import dask
dask.config.set(scheduler="synchronous")

from tensorflow.keras import layers, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

matplotlib.rc('font', **font)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
region_division = gpd.read_file('~/work/jacopo/DATA/regions/region_division.shp', crs="epsg:4326")
#region_division = world

himalaya = Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])
himalaya = gpd.GeoDataFrame({'geometry': [Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])]})
hkk = Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])
hkk = gpd.GeoDataFrame({'geometry': [Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])]})
# Out:
# 2022-10-13 19:14:50.850063: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-13 19:14:50.988619: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:14:50.988641: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-13 19:14:51.017242: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-13 19:14:51.600700: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:14:51.600805: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:14:51.600813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
n_eof_comp = 3
fields = ['tp']
lat_boundaries = [5,40]
lon_boundaries = [65,100]

d = xr.open_mfdataset("/archive/paolo/cmip6/CMIP6/model-output/EC-Earth-Consortium/EC-Earth3/historical/atmos/day/r1i1p1f1/pr/*.nc").drop(['time_bnds','lat_bnds','lon_bnds']).rename(pr = 'tp')*86400
a = xr.open_mfdataset("/home/paolo/archive/cmip6/CMIP6/model-output/EC-Earth-Consortium/EC-Earth3/ssp585/atmos/day/r1i1p1f1/pr/*.nc").drop(['time_bnds','lat_bnds','lon_bnds']).rename(pr = 'tp')*86400
dataset = xr.concat([d,a],'time')
dataset = dataset.sortby(['lat']).sortby(['lon'])
dataset = dataset.sel(lat=slice(np.min(lat_boundaries),np.max(lat_boundaries)), lon=slice(np.min(lon_boundaries),np.max(lon_boundaries))).load()

#dataset = xr.open_dataset("~/work/jacopo/DATA/ERA5_prec_day_INDIA.nc").drop("time_bnds").rename(tp = 'tp')*24000

dataset = dataset.resample(time='1D').first()
dataset = dataset.sel(time=~((dataset['time.month'] == 2) & (dataset['time.day'] == 29)))
dataset = dataset.rolling(time=30, center=True).mean().fillna(0)

# %%
to_see = 'hkk'

if to_see == 'him':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True)
    data = data.rio.clip(himalaya.geometry.apply(mapping), himalaya.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
elif to_see == 'hkk':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True) 
    data = dataset.rio.clip(hkk.geometry.apply(mapping), hkk.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
else:
    print('none')

# %%
###################################################################
data_to_train = data.sel(time=slice('1980','2000'))
data_to_train_doy = data_to_train.groupby('time.dayofyear').mean()
data_to_train_doy = data_to_train_doy.sel(dayofyear=~(data_to_train_doy['dayofyear'] == 50))
data_to_train = data_to_train.drop('spatial_ref')
###################################################################

# %%
# Creating base for seasonal division
seasons_names = ['winter','spring','summer','autumn']

to_eof = []
for i in fields:
    supp = getattr(data_to_train_doy,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())

solver = MultivariateEof(to_eof)
pc = solver.pcs(npcs = n_eof_comp)

len_consistancy_check = True
min_len = 20
learning_rate = 1
scheduling_factor = 1.1
l_r_scheduler = True
n_iter = 1000
n_seas = 4

model = Radially_Constrained_Cluster(pc, n_seas, n_iter, 
                                learning_rate, l_r_scheduler, scheduling_factor, 
                                len_consistancy_check, min_len)

model.fit()
prediction = model.get_prediction()


plt.figure(figsize = (15,6))
plt.plot(model.error_story)
plt.grid()
plt.xlabel('N° iterations')
plt.ylabel('Within-Cluster Sum of Square')

cc = model.get_centroids()
print(f'Final error: {model.get_final_error()}')
print(f'Breakpoints: {model.breakpoints}')

fig, ax = plt.subplots(figsize = (15,6))
scatter = ax.scatter(range(np.size(pc, axis=0)), data_to_train_doy.tp.mean(['lat','lon']), c = prediction)
legend1 = ax.legend(handles=scatter.legend_elements()[0], labels=seasons_names)
ax.set_title('Seasonal clustering')
ax.add_artist(legend1)
ax.grid()
ax.set_xlabel('julian day')
ax.set_ylabel('Tp [mm/day]')
ax.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])


fig, axs = plt.subplots(1,2, figsize = (18,6), sharey = True, sharex=True)
axs[0].scatter(pc[:,0],pc[:,1], c = prediction )
for i in range(n_seas):
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
axs[0].grid()
axs[0].set_xlabel('PC 1')
axs[0].set_ylabel('PC 2')

axs[1].scatter(pc[:,0],pc[:,2], c = prediction)
axs[1].grid()
axs[1].set_xlabel('PC 1')
axs[1].set_ylabel('PC 3')
# Out:
# Final error: 3952.518952708845
# Breakpoints: [ 68 159 265 328]
# Text(0, 0.5, 'PC 3')

# %%
to_eof = []
for i in fields:
    supp = getattr(data_to_train,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())


pc_train = solver.projectField(to_eof)
pc_train = pc_train[:,0:n_eof_comp]

y_train = np.squeeze(np.array([prediction]*21).reshape((365*21,1)))

# %%
np.shape(pc_train)
# Out:
# (7665, 3)

# %%
input = layers.Input(shape=(n_eof_comp))

# Encoder
x = layers.Dense(3, activation='relu')(input)
x = layers.Dense(4, activation='relu')(x)
x = layers.Dense(5, activation='relu')(x)
x = layers.Dense(n_seas, activation='softmax')(x)


# Autoencoder
lstm_net = Model(input, x)
lstm_net.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics='accuracy')
lstm_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 3)                 12
#
#  dense_1 (Dense)             (None, 4)                 16
#
#  dense_2 (Dense)             (None, 5)                 25
#
#  dense_3 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# _________________________________________________________________
# 2022-10-13 19:30:58.040731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:30:58.040769: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-13 19:30:58.040795: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (wilma): /proc/driver/nvidia/version does not exist
# 2022-10-13 19:30:58.041094: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_history = lstm_net.fit(
    x=pc_train,
    y=y_train,
    epochs=200,
    batch_size=128,
#    validation_data = pc_vale,
    validation_split = 0.2,
    shuffle=True
)

plt.figure()
plt.plot(model_history.history["loss"], label='loss')
plt.plot(model_history.history["val_loss"], label='validation loss')
plt.title("Loss vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)


plt.figure()
plt.plot(model_history.history["accuracy"], label='accuracy')
plt.plot(model_history.history["val_accuracy"], label='validation accuracy')
plt.title("Accuracy vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
# Out:
# Epoch 1/200
# 48/48 [==============================] - 1s 6ms/step - loss: 1.4727 - accuracy: 0.1760 - val_loss: 1.4297 - val_accuracy: 0.1872
# Epoch 2/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.3933 - accuracy: 0.1751 - val_loss: 1.3748 - val_accuracy: 0.1794
# Epoch 3/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.3469 - accuracy: 0.2776 - val_loss: 1.3297 - val_accuracy: 0.3399
# Epoch 4/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.2979 - accuracy: 0.3493 - val_loss: 1.2798 - val_accuracy: 0.3275
# Epoch 5/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.2445 - accuracy: 0.3666 - val_loss: 1.2326 - val_accuracy: 0.3816
# Epoch 6/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.1933 - accuracy: 0.4134 - val_loss: 1.1985 - val_accuracy: 0.4005
# Epoch 7/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.1515 - accuracy: 0.4442 - val_loss: 1.1798 - val_accuracy: 0.4188
# Epoch 8/200
# 48/48 [==============================] - 0s 3ms/step - loss: 1.1187 - accuracy: 0.4648 - val_loss: 1.1655 - val_accuracy: 0.4788
# Epoch 9/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0871 - accuracy: 0.4799 - val_loss: 1.1529 - val_accuracy: 0.4873
# Epoch 10/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0598 - accuracy: 0.4925 - val_loss: 1.1453 - val_accuracy: 0.4925
# Epoch 11/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0402 - accuracy: 0.4966 - val_loss: 1.1446 - val_accuracy: 0.5029
# Epoch 12/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0276 - accuracy: 0.5036 - val_loss: 1.1526 - val_accuracy: 0.5003
# Epoch 13/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0188 - accuracy: 0.5059 - val_loss: 1.1593 - val_accuracy: 0.5029
# Epoch 14/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0122 - accuracy: 0.5132 - val_loss: 1.1613 - val_accuracy: 0.5356
# Epoch 15/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0069 - accuracy: 0.5657 - val_loss: 1.1592 - val_accuracy: 0.5532
# Epoch 16/200
# 48/48 [==============================] - 0s 2ms/step - loss: 1.0027 - accuracy: 0.5660 - val_loss: 1.1590 - val_accuracy: 0.5603
# Epoch 17/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.9985 - accuracy: 0.5698 - val_loss: 1.1597 - val_accuracy: 0.5525
# Epoch 18/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.9950 - accuracy: 0.5735 - val_loss: 1.1605 - val_accuracy: 0.5629
# Epoch 19/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9917 - accuracy: 0.5711 - val_loss: 1.1505 - val_accuracy: 0.5819
# Epoch 20/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9885 - accuracy: 0.5750 - val_loss: 1.1459 - val_accuracy: 0.5603
# Epoch 21/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9851 - accuracy: 0.5749 - val_loss: 1.1433 - val_accuracy: 0.5610
# Epoch 22/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9819 - accuracy: 0.5820 - val_loss: 1.1339 - val_accuracy: 0.5584
# Epoch 23/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9787 - accuracy: 0.5835 - val_loss: 1.1383 - val_accuracy: 0.5532
# Epoch 24/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9758 - accuracy: 0.5846 - val_loss: 1.1304 - val_accuracy: 0.5610
# Epoch 25/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9725 - accuracy: 0.5855 - val_loss: 1.1283 - val_accuracy: 0.5708
# Epoch 26/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9695 - accuracy: 0.5902 - val_loss: 1.1222 - val_accuracy: 0.5806
# Epoch 27/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9659 - accuracy: 0.5921 - val_loss: 1.1196 - val_accuracy: 0.5812
# Epoch 28/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.9623 - accuracy: 0.5946 - val_loss: 1.1135 - val_accuracy: 0.5838
# Epoch 29/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9588 - accuracy: 0.5992 - val_loss: 1.1080 - val_accuracy: 0.5884
# Epoch 30/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9552 - accuracy: 0.6027 - val_loss: 1.1079 - val_accuracy: 0.5845
# Epoch 31/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9511 - accuracy: 0.6058 - val_loss: 1.1058 - val_accuracy: 0.5858
# Epoch 32/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9467 - accuracy: 0.6135 - val_loss: 1.1029 - val_accuracy: 0.5890
# Epoch 33/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9416 - accuracy: 0.6150 - val_loss: 1.0942 - val_accuracy: 0.5864
# Epoch 34/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9355 - accuracy: 0.6221 - val_loss: 1.0918 - val_accuracy: 0.5936
# Epoch 35/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9290 - accuracy: 0.6269 - val_loss: 1.0862 - val_accuracy: 0.5956
# Epoch 36/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9217 - accuracy: 0.6329 - val_loss: 1.0757 - val_accuracy: 0.6001
# Epoch 37/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.9137 - accuracy: 0.6394 - val_loss: 1.0716 - val_accuracy: 0.6040
# Epoch 38/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.9053 - accuracy: 0.6448 - val_loss: 1.0624 - val_accuracy: 0.6086
# Epoch 39/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8965 - accuracy: 0.6461 - val_loss: 1.0514 - val_accuracy: 0.6204
# Epoch 40/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8876 - accuracy: 0.6486 - val_loss: 1.0465 - val_accuracy: 0.6184
# Epoch 41/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8794 - accuracy: 0.6494 - val_loss: 1.0382 - val_accuracy: 0.6190
# Epoch 42/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8710 - accuracy: 0.6539 - val_loss: 1.0346 - val_accuracy: 0.6177
# Epoch 43/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8633 - accuracy: 0.6564 - val_loss: 1.0308 - val_accuracy: 0.6223
# Epoch 44/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8557 - accuracy: 0.6603 - val_loss: 1.0219 - val_accuracy: 0.6360
# Epoch 45/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8484 - accuracy: 0.6683 - val_loss: 1.0202 - val_accuracy: 0.6354
# Epoch 46/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8396 - accuracy: 0.6769 - val_loss: 1.0151 - val_accuracy: 0.6341
# Epoch 47/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8324 - accuracy: 0.6758 - val_loss: 1.0122 - val_accuracy: 0.6373
# Epoch 48/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8252 - accuracy: 0.6802 - val_loss: 1.0086 - val_accuracy: 0.6445
# Epoch 49/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8197 - accuracy: 0.6835 - val_loss: 1.0108 - val_accuracy: 0.6425
# Epoch 50/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8135 - accuracy: 0.6840 - val_loss: 1.0094 - val_accuracy: 0.6464
# Epoch 51/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8086 - accuracy: 0.6833 - val_loss: 1.0055 - val_accuracy: 0.6458
# Epoch 52/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8046 - accuracy: 0.6844 - val_loss: 1.0025 - val_accuracy: 0.6543
# Epoch 53/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.8005 - accuracy: 0.6857 - val_loss: 1.0050 - val_accuracy: 0.6484
# Epoch 54/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7976 - accuracy: 0.6846 - val_loss: 1.0030 - val_accuracy: 0.6491
# Epoch 55/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7945 - accuracy: 0.6848 - val_loss: 0.9985 - val_accuracy: 0.6634
# Epoch 56/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7909 - accuracy: 0.6854 - val_loss: 0.9999 - val_accuracy: 0.6634
# Epoch 57/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7871 - accuracy: 0.6838 - val_loss: 0.9905 - val_accuracy: 0.6686
# Epoch 58/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7846 - accuracy: 0.6848 - val_loss: 0.9873 - val_accuracy: 0.6654
# Epoch 59/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7817 - accuracy: 0.6841 - val_loss: 0.9862 - val_accuracy: 0.6712
# Epoch 60/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7784 - accuracy: 0.6851 - val_loss: 0.9805 - val_accuracy: 0.6706
# Epoch 61/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7751 - accuracy: 0.6867 - val_loss: 0.9813 - val_accuracy: 0.6719
# Epoch 62/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7716 - accuracy: 0.6895 - val_loss: 0.9737 - val_accuracy: 0.6725
# Epoch 63/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7681 - accuracy: 0.6890 - val_loss: 0.9684 - val_accuracy: 0.6732
# Epoch 64/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7650 - accuracy: 0.6918 - val_loss: 0.9675 - val_accuracy: 0.6719
# Epoch 65/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7621 - accuracy: 0.6942 - val_loss: 0.9578 - val_accuracy: 0.6765
# Epoch 66/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7596 - accuracy: 0.6967 - val_loss: 0.9513 - val_accuracy: 0.6738
# Epoch 67/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7566 - accuracy: 0.7008 - val_loss: 0.9497 - val_accuracy: 0.6725
# Epoch 68/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7525 - accuracy: 0.7037 - val_loss: 0.9453 - val_accuracy: 0.6784
# Epoch 69/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7490 - accuracy: 0.7079 - val_loss: 0.9398 - val_accuracy: 0.6778
# Epoch 70/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7462 - accuracy: 0.7092 - val_loss: 0.9336 - val_accuracy: 0.6660
# Epoch 71/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7439 - accuracy: 0.7099 - val_loss: 0.9306 - val_accuracy: 0.6673
# Epoch 72/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7407 - accuracy: 0.7105 - val_loss: 0.9246 - val_accuracy: 0.6706
# Epoch 73/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7390 - accuracy: 0.7092 - val_loss: 0.9240 - val_accuracy: 0.6719
# Epoch 74/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7391 - accuracy: 0.7107 - val_loss: 0.9189 - val_accuracy: 0.6725
# Epoch 75/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7361 - accuracy: 0.7127 - val_loss: 0.9161 - val_accuracy: 0.6654
# Epoch 76/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7345 - accuracy: 0.7099 - val_loss: 0.9189 - val_accuracy: 0.6660
# Epoch 77/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7334 - accuracy: 0.7127 - val_loss: 0.9173 - val_accuracy: 0.6680
# Epoch 78/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7321 - accuracy: 0.7096 - val_loss: 0.9190 - val_accuracy: 0.6686
# Epoch 79/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7317 - accuracy: 0.7112 - val_loss: 0.9177 - val_accuracy: 0.6686
# Epoch 80/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7296 - accuracy: 0.7122 - val_loss: 0.9122 - val_accuracy: 0.6673
# Epoch 81/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7282 - accuracy: 0.7158 - val_loss: 0.9129 - val_accuracy: 0.6667
# Epoch 82/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7277 - accuracy: 0.7112 - val_loss: 0.9173 - val_accuracy: 0.6673
# Epoch 83/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7271 - accuracy: 0.7140 - val_loss: 0.9125 - val_accuracy: 0.6693
# Epoch 84/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7266 - accuracy: 0.7120 - val_loss: 0.9145 - val_accuracy: 0.6680
# Epoch 85/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7249 - accuracy: 0.7172 - val_loss: 0.9205 - val_accuracy: 0.6673
# Epoch 86/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7241 - accuracy: 0.7159 - val_loss: 0.9151 - val_accuracy: 0.6699
# Epoch 87/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7237 - accuracy: 0.7159 - val_loss: 0.9155 - val_accuracy: 0.6699
# Epoch 88/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7230 - accuracy: 0.7182 - val_loss: 0.9097 - val_accuracy: 0.6673
# Epoch 89/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7223 - accuracy: 0.7172 - val_loss: 0.9083 - val_accuracy: 0.6673
# Epoch 90/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7216 - accuracy: 0.7220 - val_loss: 0.9157 - val_accuracy: 0.6641
# Epoch 91/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7212 - accuracy: 0.7174 - val_loss: 0.9132 - val_accuracy: 0.6660
# Epoch 92/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7204 - accuracy: 0.7195 - val_loss: 0.9134 - val_accuracy: 0.6660
# Epoch 93/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7197 - accuracy: 0.7223 - val_loss: 0.9123 - val_accuracy: 0.6654
# Epoch 94/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7198 - accuracy: 0.7195 - val_loss: 0.9158 - val_accuracy: 0.6647
# Epoch 95/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7189 - accuracy: 0.7211 - val_loss: 0.9123 - val_accuracy: 0.6621
# Epoch 96/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7178 - accuracy: 0.7228 - val_loss: 0.9120 - val_accuracy: 0.6660
# Epoch 97/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7180 - accuracy: 0.7197 - val_loss: 0.9115 - val_accuracy: 0.6673
# Epoch 98/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7175 - accuracy: 0.7208 - val_loss: 0.9167 - val_accuracy: 0.6667
# Epoch 99/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7168 - accuracy: 0.7233 - val_loss: 0.9221 - val_accuracy: 0.6667
# Epoch 100/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7165 - accuracy: 0.7197 - val_loss: 0.9157 - val_accuracy: 0.6660
# Epoch 101/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7148 - accuracy: 0.7226 - val_loss: 0.9231 - val_accuracy: 0.6641
# Epoch 102/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7144 - accuracy: 0.7211 - val_loss: 0.9215 - val_accuracy: 0.6614
# Epoch 103/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7147 - accuracy: 0.7172 - val_loss: 0.9135 - val_accuracy: 0.6647
# Epoch 104/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7133 - accuracy: 0.7220 - val_loss: 0.9171 - val_accuracy: 0.6654
# Epoch 105/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7129 - accuracy: 0.7223 - val_loss: 0.9199 - val_accuracy: 0.6614
# Epoch 106/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7126 - accuracy: 0.7224 - val_loss: 0.9200 - val_accuracy: 0.6628
# Epoch 107/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7121 - accuracy: 0.7223 - val_loss: 0.9096 - val_accuracy: 0.6673
# Epoch 108/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7118 - accuracy: 0.7203 - val_loss: 0.9123 - val_accuracy: 0.6608
# Epoch 109/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7108 - accuracy: 0.7226 - val_loss: 0.9175 - val_accuracy: 0.6608
# Epoch 110/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7121 - accuracy: 0.7200 - val_loss: 0.9185 - val_accuracy: 0.6641
# Epoch 111/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7111 - accuracy: 0.7189 - val_loss: 0.9121 - val_accuracy: 0.6706
# Epoch 112/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7102 - accuracy: 0.7205 - val_loss: 0.9176 - val_accuracy: 0.6614
# Epoch 113/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7098 - accuracy: 0.7208 - val_loss: 0.9137 - val_accuracy: 0.6654
# Epoch 114/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7093 - accuracy: 0.7220 - val_loss: 0.9154 - val_accuracy: 0.6621
# Epoch 115/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7098 - accuracy: 0.7192 - val_loss: 0.9106 - val_accuracy: 0.6745
# Epoch 116/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7089 - accuracy: 0.7228 - val_loss: 0.9171 - val_accuracy: 0.6628
# Epoch 117/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7090 - accuracy: 0.7223 - val_loss: 0.9170 - val_accuracy: 0.6621
# Epoch 118/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7086 - accuracy: 0.7220 - val_loss: 0.9139 - val_accuracy: 0.6628
# Epoch 119/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7081 - accuracy: 0.7223 - val_loss: 0.9123 - val_accuracy: 0.6628
# Epoch 120/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7081 - accuracy: 0.7228 - val_loss: 0.9053 - val_accuracy: 0.6628
# Epoch 121/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7077 - accuracy: 0.7231 - val_loss: 0.9118 - val_accuracy: 0.6621
# Epoch 122/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7072 - accuracy: 0.7216 - val_loss: 0.9152 - val_accuracy: 0.6608
# Epoch 123/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7073 - accuracy: 0.7208 - val_loss: 0.9137 - val_accuracy: 0.6608
# Epoch 124/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7069 - accuracy: 0.7202 - val_loss: 0.9147 - val_accuracy: 0.6569
# Epoch 125/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7057 - accuracy: 0.7220 - val_loss: 0.9061 - val_accuracy: 0.6588
# Epoch 126/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7063 - accuracy: 0.7220 - val_loss: 0.9155 - val_accuracy: 0.6595
# Epoch 127/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7064 - accuracy: 0.7224 - val_loss: 0.9074 - val_accuracy: 0.6614
# Epoch 128/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7053 - accuracy: 0.7231 - val_loss: 0.9076 - val_accuracy: 0.6569
# Epoch 129/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7059 - accuracy: 0.7236 - val_loss: 0.9034 - val_accuracy: 0.6628
# Epoch 130/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7050 - accuracy: 0.7211 - val_loss: 0.9103 - val_accuracy: 0.6575
# Epoch 131/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7046 - accuracy: 0.7233 - val_loss: 0.9072 - val_accuracy: 0.6621
# Epoch 132/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7043 - accuracy: 0.7210 - val_loss: 0.9057 - val_accuracy: 0.6575
# Epoch 133/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7044 - accuracy: 0.7211 - val_loss: 0.9078 - val_accuracy: 0.6556
# Epoch 134/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7043 - accuracy: 0.7241 - val_loss: 0.9057 - val_accuracy: 0.6614
# Epoch 135/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7038 - accuracy: 0.7200 - val_loss: 0.8974 - val_accuracy: 0.6582
# Epoch 136/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7036 - accuracy: 0.7228 - val_loss: 0.9039 - val_accuracy: 0.6582
# Epoch 137/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7028 - accuracy: 0.7246 - val_loss: 0.9022 - val_accuracy: 0.6595
# Epoch 138/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7032 - accuracy: 0.7221 - val_loss: 0.8971 - val_accuracy: 0.6569
# Epoch 139/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7023 - accuracy: 0.7229 - val_loss: 0.9118 - val_accuracy: 0.6523
# Epoch 140/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7025 - accuracy: 0.7250 - val_loss: 0.9012 - val_accuracy: 0.6517
# Epoch 141/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7023 - accuracy: 0.7231 - val_loss: 0.9088 - val_accuracy: 0.6543
# Epoch 142/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7017 - accuracy: 0.7254 - val_loss: 0.9016 - val_accuracy: 0.6621
# Epoch 143/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7015 - accuracy: 0.7237 - val_loss: 0.9075 - val_accuracy: 0.6569
# Epoch 144/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7016 - accuracy: 0.7241 - val_loss: 0.9023 - val_accuracy: 0.6530
# Epoch 145/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7011 - accuracy: 0.7237 - val_loss: 0.9086 - val_accuracy: 0.6471
# Epoch 146/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7012 - accuracy: 0.7247 - val_loss: 0.9036 - val_accuracy: 0.6556
# Epoch 147/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7004 - accuracy: 0.7244 - val_loss: 0.8969 - val_accuracy: 0.6588
# Epoch 148/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7011 - accuracy: 0.7242 - val_loss: 0.9050 - val_accuracy: 0.6641
# Epoch 149/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7000 - accuracy: 0.7249 - val_loss: 0.8979 - val_accuracy: 0.6693
# Epoch 150/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.7260 - val_loss: 0.9041 - val_accuracy: 0.6582
# Epoch 151/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7000 - accuracy: 0.7237 - val_loss: 0.9087 - val_accuracy: 0.6601
# Epoch 152/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6997 - accuracy: 0.7242 - val_loss: 0.9068 - val_accuracy: 0.6562
# Epoch 153/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6998 - accuracy: 0.7242 - val_loss: 0.8983 - val_accuracy: 0.6575
# Epoch 154/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.7001 - accuracy: 0.7260 - val_loss: 0.9006 - val_accuracy: 0.6634
# Epoch 155/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6993 - accuracy: 0.7277 - val_loss: 0.9081 - val_accuracy: 0.6634
# Epoch 156/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6987 - accuracy: 0.7265 - val_loss: 0.9039 - val_accuracy: 0.6660
# Epoch 157/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6990 - accuracy: 0.7268 - val_loss: 0.9046 - val_accuracy: 0.6719
# Epoch 158/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6990 - accuracy: 0.7280 - val_loss: 0.9078 - val_accuracy: 0.6595
# Epoch 159/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6986 - accuracy: 0.7265 - val_loss: 0.9034 - val_accuracy: 0.6634
# Epoch 160/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6986 - accuracy: 0.7268 - val_loss: 0.9047 - val_accuracy: 0.6562
# Epoch 161/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6988 - accuracy: 0.7270 - val_loss: 0.9074 - val_accuracy: 0.6562
# Epoch 162/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.7242 - val_loss: 0.9058 - val_accuracy: 0.6530
# Epoch 163/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6981 - accuracy: 0.7267 - val_loss: 0.9084 - val_accuracy: 0.6523
# Epoch 164/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6981 - accuracy: 0.7267 - val_loss: 0.9036 - val_accuracy: 0.6628
# Epoch 165/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6973 - accuracy: 0.7267 - val_loss: 0.9086 - val_accuracy: 0.6523
# Epoch 166/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6974 - accuracy: 0.7281 - val_loss: 0.9089 - val_accuracy: 0.6778
# Epoch 167/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6980 - accuracy: 0.7272 - val_loss: 0.9091 - val_accuracy: 0.6543
# Epoch 168/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6975 - accuracy: 0.7285 - val_loss: 0.9043 - val_accuracy: 0.6647
# Epoch 169/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6969 - accuracy: 0.7262 - val_loss: 0.9122 - val_accuracy: 0.6614
# Epoch 170/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6971 - accuracy: 0.7278 - val_loss: 0.9089 - val_accuracy: 0.6569
# Epoch 171/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6966 - accuracy: 0.7278 - val_loss: 0.9182 - val_accuracy: 0.6510
# Epoch 172/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6968 - accuracy: 0.7275 - val_loss: 0.8963 - val_accuracy: 0.6673
# Epoch 173/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.7246 - val_loss: 0.9185 - val_accuracy: 0.6464
# Epoch 174/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6966 - accuracy: 0.7281 - val_loss: 0.9084 - val_accuracy: 0.6647
# Epoch 175/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.7291 - val_loss: 0.8985 - val_accuracy: 0.6628
# Epoch 176/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6959 - accuracy: 0.7298 - val_loss: 0.9089 - val_accuracy: 0.6647
# Epoch 177/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.7293 - val_loss: 0.9092 - val_accuracy: 0.6582
# Epoch 178/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6963 - accuracy: 0.7308 - val_loss: 0.9089 - val_accuracy: 0.6810
# Epoch 179/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.7288 - val_loss: 0.9047 - val_accuracy: 0.6693
# Epoch 180/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6957 - accuracy: 0.7286 - val_loss: 0.9037 - val_accuracy: 0.6706
# Epoch 181/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.7301 - val_loss: 0.9081 - val_accuracy: 0.6601
# Epoch 182/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.7291 - val_loss: 0.9221 - val_accuracy: 0.6549
# Epoch 183/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6959 - accuracy: 0.7277 - val_loss: 0.9130 - val_accuracy: 0.6523
# Epoch 184/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6948 - accuracy: 0.7286 - val_loss: 0.9117 - val_accuracy: 0.6608
# Epoch 185/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6948 - accuracy: 0.7290 - val_loss: 0.9097 - val_accuracy: 0.6504
# Epoch 186/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6944 - accuracy: 0.7316 - val_loss: 0.9198 - val_accuracy: 0.6549
# Epoch 187/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.7319 - val_loss: 0.9153 - val_accuracy: 0.6491
# Epoch 188/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.7330 - val_loss: 0.9151 - val_accuracy: 0.6549
# Epoch 189/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6934 - accuracy: 0.7342 - val_loss: 0.9055 - val_accuracy: 0.6588
# Epoch 190/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.7312 - val_loss: 0.9213 - val_accuracy: 0.6523
# Epoch 191/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.7322 - val_loss: 0.9089 - val_accuracy: 0.6575
# Epoch 192/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.7332 - val_loss: 0.9141 - val_accuracy: 0.6719
# Epoch 193/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.7340 - val_loss: 0.9112 - val_accuracy: 0.6608
# Epoch 194/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.7298 - val_loss: 0.9115 - val_accuracy: 0.6562
# Epoch 195/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.7296 - val_loss: 0.9216 - val_accuracy: 0.6641
# Epoch 196/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.7326 - val_loss: 0.9138 - val_accuracy: 0.6562
# Epoch 197/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.7327 - val_loss: 0.9161 - val_accuracy: 0.6491
# Epoch 198/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.7321 - val_loss: 0.9168 - val_accuracy: 0.6543
# Epoch 199/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.7342 - val_loss: 0.9086 - val_accuracy: 0.6588
# Epoch 200/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.7299 - val_loss: 0.9249 - val_accuracy: 0.6536

# %%
p = []
peri = []
s_index = []

for i in tqdm(np.arange(0,40,10)):

    plt.figure(figsize=(15,6))
    sleep(3)
    data_to_test = data.sel(time=slice(str(1970+i),str(1990+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    #pc_test = (pc_test)/pc_test.max(axis=0)
    pred_season = lstm_net.predict(pc_test, verbose = 0)
    p.append(pred_season)

    for i in range(n_seas):

        plt.plot(range(0,len(pred_season)),pred_season[:,i], label=f'{seasons_names[i]}')
    
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
    plt.grid()
    plt.legend()
    plt.ylabel('prob')
    plt.title(f"{data_to_test['time.year'][0].to_numpy()} - {data_to_test['time.year'][-1].to_numpy()}")
    s_index.append(pred_season.argmax(-1))
# Out:
# 100%|██████████| 4/4 [00:13<00:00,  3.46s/it]

# %%
fig, ax = plt.subplots(4,1, figsize=(15,24))

for j in range(len(peri)):

    ax[0].plot(range(0,len(pred_season)),p[j][:,0])
    ax[0].set_title(f'{seasons_names[0]}')
    ax[1].plot(range(0,len(pred_season)),p[j][:,1])
    ax[1].set_title(f'{seasons_names[1]}')
    ax[2].plot(range(0,len(pred_season)),p[j][:,2], label = f'{peri[j][0]} - {peri[j][1]}')
    ax[2].set_title(f'{seasons_names[2]}')
    ax[3].plot(range(0,len(pred_season)),p[j][:,3])
    ax[3].set_title(f'{seasons_names[3]}')

for i in ax:
    i.set_ylabel('prob')
    i.grid()
    i.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])



fig.legend(loc = 'center right')

# %%
p = []
peri = []
s_index = []
s_len = []
s_mean = []
yr = []

for i in tqdm(np.arange(0,230,1)):

    sleep(3)
    data_to_test = data.sel(time=slice(str(1850+i),str(1870+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    l_t = data_to_test_doy.mean(['lat','lon']).tp.to_numpy()
    l_t = l_t[0:365]

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    pred_season = lstm_net.predict(pc_test, verbose=0)
    p.append(pred_season)

    predi = pred_season.argmax(-1)
    
    s_index.append(predi)

    len_seas = np.empty((n_seas,1))
    mean_seas = np.empty((n_seas,1))

    for k in range(n_seas):
        len_seas[k] = np.count_nonzero(predi==k)
        mean_seas[k] = np.mean(l_t[predi==k])

    s_len.append(len_seas)
    s_mean.append(mean_seas)
# Out:
#  14%|█▍        | 32/230 [01:47<11:04,  3.35s/it]/home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  14%|█▍        | 33/230 [01:51<11:02,  3.36s/it]/home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  15%|█▍        | 34/230 [01:54<11:14,  3.44s/it]/home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  15%|█▌        | 35/230 [01:57<11:04,  3.41s/it]/home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
#  18%|█▊        | 41/230 [02:18<10:32,  3.35s/it]/home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/work/jacopo/env/anaconda3/envs/RCC/lib/python3.10/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 230/230 [12:54<00:00,  3.37s/it]

# %%
s_len = np.array(s_len)
s_mean = np.array(s_mean)

plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_len[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season length')


plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_mean[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season mean')
# Out:
# Text(0.5, 1.0, 'Season mean')

# %%
pr = np.squeeze(np.array(p))
plt.figure(figsize=(20,5))
ps = np.squeeze(np.array(peri))


for i in range(n_seas):
    plt.figure(figsize=(15,10))
    cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)
    plt.title(seasons_names[i])
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
# Out:
# /tmp/ipykernel_988389/2417149041.py:8: UserWarning: The following kwargs were not used by contour: 'vamx'
#   cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)

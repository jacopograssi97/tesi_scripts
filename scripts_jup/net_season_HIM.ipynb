# %%
import numpy as np
from radial_constrained_cluster_copy import *
import matplotlib.pyplot as plt
import matplotlib
import random
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import xarray as xr
from xarray import Dataset
from eofs.multivariate.standard import MultivariateEof
from shapely.geometry import mapping
from sklearn.cluster import KMeans
from scipy import signal
from obspy.signal.tf_misfit import cwt
import pymannkendall as mk
from tqdm import tqdm
from time import sleep

import dask
dask.config.set(scheduler="synchronous")

from tensorflow.keras import layers, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 13}

matplotlib.rc('font', **font)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
region_division = gpd.read_file('~/work/jacopo/DATA/regions/region_division.shp', crs="epsg:4326")
#region_division = world

himalaya = Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])
himalaya = gpd.GeoDataFrame({'geometry': [Polygon([(78, 25), (93, 25), (93, 32), (78, 32)])]})
hkk = Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])
hkk = gpd.GeoDataFrame({'geometry': [Polygon([(71, 32), (78, 32), (78, 37), (71, 37)])]})
# Out:
# 2022-10-13 19:09:17.762956: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-13 19:09:17.901591: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:09:17.901616: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-13 19:09:17.929368: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-13 19:09:18.493274: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:09:18.493376: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:09:18.493383: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
n_eof_comp = 3
fields = ['tp']

dataset = xr.open_dataset("~/work/jacopo/DATA/ERA5_prec_day_INDIA.nc").drop("time_bnds").rename(tp = 'tp')*24000
dataset = dataset.resample(time='1D').first()
dataset = dataset.sel(time=~((dataset['time.month'] == 2) & (dataset['time.day'] == 29)))
dataset = dataset.rolling(time=30, center=True).mean().fillna(0)

# %%
to_see = 'him'

if to_see == 'him':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True)
    data = data.rio.clip(himalaya.geometry.apply(mapping), himalaya.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
elif to_see == 'hkk':
    data = dataset.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    data = data.rio.write_crs("epsg:4326", inplace=True) 
    data = dataset.rio.clip(hkk.geometry.apply(mapping), hkk.crs, drop=False)
    data_doy = data.groupby('time.dayofyear').mean()
    
else:
    print('none')

# %%
###################################################################
data_to_train = data.sel(time=slice('1980','2000'))
data_to_train_doy = data_to_train.groupby('time.dayofyear').mean()
data_to_train_doy = data_to_train_doy.sel(dayofyear=~(data_to_train_doy['dayofyear'] == 50))
data_to_train = data_to_train.drop('spatial_ref')
###################################################################

# %%
# Creating base for seasonal division
seasons_names = ['dry','monsoon']

to_eof = []
for i in fields:
    supp = getattr(data_to_train_doy,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())

solver = MultivariateEof(to_eof)
pc = solver.pcs(npcs = n_eof_comp)

len_consistancy_check = True
min_len = 10
learning_rate = 50
scheduling_factor = 1.1
l_r_scheduler = True
n_iter = 10000
n_seas = 2

model = Radially_Constrained_Cluster(pc, n_seas, n_iter, 
                                learning_rate, l_r_scheduler, scheduling_factor, 
                                len_consistancy_check, min_len)

model.fit()
prediction = model.get_prediction()


plt.figure(figsize = (15,6))
plt.plot(model.error_story)
plt.grid()
plt.xlabel('N° iterations')
plt.ylabel('Within-Cluster Sum of Square')

cc = model.get_centroids()
print(f'Final error: {model.get_final_error()}')
print(f'Breakpoints: {model.breakpoints}')

fig, ax = plt.subplots(figsize = (15,6))
scatter = ax.scatter(range(np.size(pc, axis=0)), data_to_train_doy.tp.mean(['lat','lon']), c = prediction)
legend1 = ax.legend(handles=scatter.legend_elements()[0], labels=seasons_names)
ax.set_title('Seasonal clustering')
ax.add_artist(legend1)
ax.grid()
ax.set_xlabel('julian day')
ax.set_ylabel('Tp [mm/day]')
ax.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])


fig, axs = plt.subplots(1,2, figsize = (18,6), sharey = True, sharex=True)
axs[0].scatter(pc[:,0],pc[:,1], c = prediction )
for i in range(n_seas):
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
    axs[0].scatter(cc[i][0],cc[i][1], s = 200)
axs[0].grid()
axs[0].set_xlabel('PC 1')
axs[0].set_ylabel('PC 2')

axs[1].scatter(pc[:,0],pc[:,2], c = prediction)
axs[1].grid()
axs[1].set_xlabel('PC 1')
axs[1].set_ylabel('PC 3')
# Out:
# Final error: 97156.37667558639
# Breakpoints: [152 262]
# Text(0, 0.5, 'PC 3')

# %%
to_eof = []
for i in fields:
    supp = getattr(data_to_train,i)
    supp = (supp-supp.mean())/supp.std()
    to_eof.append(supp.to_numpy())


pc_train = solver.projectField(to_eof)
pc_train = pc_train[:,0:n_eof_comp]

y_train = np.squeeze(np.array([prediction]*21).reshape((365*21,1)))

# %%
np.shape(pc_train)
# Out:
# (7665, 3)

# %%
input = layers.Input(shape=(n_eof_comp))

# Encoder
x = layers.Dense(4, activation='relu')(input)
x = layers.Dense(8, activation='relu')(x)
x = layers.Dense(n_seas, activation='softmax')(x)


# Autoencoder
lstm_net = Model(input, x)
lstm_net.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics='accuracy')
lstm_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 8)                 40
#
#  dense_2 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 74
# Trainable params: 74
# Non-trainable params: 0
# _________________________________________________________________
# 2022-10-13 19:09:59.872734: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/Compiler/11.0/084/lib/intel64:/opt/intel/Compiler/11.0/084/mkl/lib/em64t
# 2022-10-13 19:09:59.872787: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-13 19:09:59.872823: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (wilma): /proc/driver/nvidia/version does not exist
# 2022-10-13 19:09:59.873564: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_history = lstm_net.fit(
    x=pc_train,
    y=y_train,
    epochs=100,
    batch_size=128,
#    validation_data = pc_vale,
    validation_split = 0.1,
    shuffle=True
)

plt.figure()
plt.plot(model_history.history["loss"], label='loss')
plt.plot(model_history.history["val_loss"], label='validation loss')
plt.title("Loss vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)


plt.figure()
plt.plot(model_history.history["accuracy"], label='accuracy')
plt.plot(model_history.history["val_accuracy"], label='validation accuracy')
plt.title("Accuracy vs. Epoch")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 1s 8ms/step - loss: 1.4844 - accuracy: 0.6970 - val_loss: 0.4237 - val_accuracy: 0.7288
# Epoch 2/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.8985 - val_loss: 0.1089 - val_accuracy: 0.9596
# Epoch 3/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1658 - accuracy: 0.9346 - val_loss: 0.0938 - val_accuracy: 0.9544
# Epoch 4/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9438 - val_loss: 0.1052 - val_accuracy: 0.9439
# Epoch 5/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1170 - accuracy: 0.9419 - val_loss: 0.1025 - val_accuracy: 0.9465
# Epoch 6/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9430 - val_loss: 0.0993 - val_accuracy: 0.9570
# Epoch 7/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9455 - val_loss: 0.1046 - val_accuracy: 0.9557
# Epoch 8/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1099 - accuracy: 0.9455 - val_loss: 0.0930 - val_accuracy: 0.9635
# Epoch 9/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.9493 - val_loss: 0.0962 - val_accuracy: 0.9635
# Epoch 10/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9490 - val_loss: 0.0885 - val_accuracy: 0.9674
# Epoch 11/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.9527 - val_loss: 0.0919 - val_accuracy: 0.9661
# Epoch 12/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9551 - val_loss: 0.0859 - val_accuracy: 0.9674
# Epoch 13/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9626 - val_loss: 0.0893 - val_accuracy: 0.9661
# Epoch 14/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9630 - val_loss: 0.0848 - val_accuracy: 0.9674
# Epoch 15/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.9648 - val_loss: 0.0894 - val_accuracy: 0.9674
# Epoch 16/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0874 - accuracy: 0.9654 - val_loss: 0.0883 - val_accuracy: 0.9674
# Epoch 17/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9665 - val_loss: 0.0980 - val_accuracy: 0.9583
# Epoch 18/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 0.9664 - val_loss: 0.0967 - val_accuracy: 0.9596
# Epoch 19/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9668 - val_loss: 0.0936 - val_accuracy: 0.9622
# Epoch 20/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9677 - val_loss: 0.0889 - val_accuracy: 0.9622
# Epoch 21/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9669 - val_loss: 0.0943 - val_accuracy: 0.9596
# Epoch 22/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 0.9668 - val_loss: 0.0878 - val_accuracy: 0.9609
# Epoch 23/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9672 - val_loss: 0.0870 - val_accuracy: 0.9622
# Epoch 24/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9667 - val_loss: 0.0988 - val_accuracy: 0.9544
# Epoch 25/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.9675 - val_loss: 0.0889 - val_accuracy: 0.9622
# Epoch 26/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.9665 - val_loss: 0.0894 - val_accuracy: 0.9609
# Epoch 27/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9668 - val_loss: 0.0873 - val_accuracy: 0.9622
# Epoch 28/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0816 - accuracy: 0.9669 - val_loss: 0.0846 - val_accuracy: 0.9635
# Epoch 29/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9661 - val_loss: 0.0938 - val_accuracy: 0.9596
# Epoch 30/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9672 - val_loss: 0.0845 - val_accuracy: 0.9648
# Epoch 31/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9668 - val_loss: 0.0867 - val_accuracy: 0.9622
# Epoch 32/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9671 - val_loss: 0.1035 - val_accuracy: 0.9531
# Epoch 33/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9674 - val_loss: 0.0936 - val_accuracy: 0.9570
# Epoch 34/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9672 - val_loss: 0.0962 - val_accuracy: 0.9570
# Epoch 35/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9669 - val_loss: 0.0964 - val_accuracy: 0.9596
# Epoch 36/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9677 - val_loss: 0.1071 - val_accuracy: 0.9478
# Epoch 37/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9667 - val_loss: 0.0955 - val_accuracy: 0.9570
# Epoch 38/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9669 - val_loss: 0.1033 - val_accuracy: 0.9557
# Epoch 39/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0809 - accuracy: 0.9672 - val_loss: 0.0940 - val_accuracy: 0.9583
# Epoch 40/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9678 - val_loss: 0.0930 - val_accuracy: 0.9596
# Epoch 41/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9674 - val_loss: 0.0870 - val_accuracy: 0.9635
# Epoch 42/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9675 - val_loss: 0.1109 - val_accuracy: 0.9465
# Epoch 43/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9668 - val_loss: 0.0914 - val_accuracy: 0.9635
# Epoch 44/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9662 - val_loss: 0.0997 - val_accuracy: 0.9557
# Epoch 45/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9672 - val_loss: 0.0927 - val_accuracy: 0.9609
# Epoch 46/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0796 - accuracy: 0.9672 - val_loss: 0.1011 - val_accuracy: 0.9518
# Epoch 47/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9672 - val_loss: 0.0874 - val_accuracy: 0.9635
# Epoch 48/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9674 - val_loss: 0.0932 - val_accuracy: 0.9583
# Epoch 49/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9669 - val_loss: 0.1035 - val_accuracy: 0.9518
# Epoch 50/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9669 - val_loss: 0.1098 - val_accuracy: 0.9492
# Epoch 51/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9668 - val_loss: 0.0957 - val_accuracy: 0.9583
# Epoch 52/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.9661 - val_loss: 0.0997 - val_accuracy: 0.9531
# Epoch 53/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0792 - accuracy: 0.9662 - val_loss: 0.0965 - val_accuracy: 0.9557
# Epoch 54/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.9667 - val_loss: 0.0948 - val_accuracy: 0.9583
# Epoch 55/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9680 - val_loss: 0.1041 - val_accuracy: 0.9518
# Epoch 56/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9672 - val_loss: 0.0895 - val_accuracy: 0.9622
# Epoch 57/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9659 - val_loss: 0.1112 - val_accuracy: 0.9465
# Epoch 58/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9669 - val_loss: 0.0881 - val_accuracy: 0.9648
# Epoch 59/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9677 - val_loss: 0.1010 - val_accuracy: 0.9570
# Epoch 60/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9667 - val_loss: 0.0913 - val_accuracy: 0.9648
# Epoch 61/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9671 - val_loss: 0.0977 - val_accuracy: 0.9609
# Epoch 62/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9678 - val_loss: 0.0971 - val_accuracy: 0.9596
# Epoch 63/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9677 - val_loss: 0.0973 - val_accuracy: 0.9609
# Epoch 64/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9662 - val_loss: 0.0983 - val_accuracy: 0.9622
# Epoch 65/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9668 - val_loss: 0.1038 - val_accuracy: 0.9544
# Epoch 66/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 0.9674 - val_loss: 0.1009 - val_accuracy: 0.9570
# Epoch 67/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9672 - val_loss: 0.0999 - val_accuracy: 0.9583
# Epoch 68/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9675 - val_loss: 0.1080 - val_accuracy: 0.9531
# Epoch 69/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9664 - val_loss: 0.0896 - val_accuracy: 0.9687
# Epoch 70/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0762 - accuracy: 0.9674 - val_loss: 0.1030 - val_accuracy: 0.9557
# Epoch 71/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9668 - val_loss: 0.0889 - val_accuracy: 0.9687
# Epoch 72/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 0.9671 - val_loss: 0.0994 - val_accuracy: 0.9635
# Epoch 73/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9667 - val_loss: 0.0868 - val_accuracy: 0.9713
# Epoch 74/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0762 - accuracy: 0.9664 - val_loss: 0.0951 - val_accuracy: 0.9674
# Epoch 75/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9664 - val_loss: 0.0892 - val_accuracy: 0.9700
# Epoch 76/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9671 - val_loss: 0.1008 - val_accuracy: 0.9635
# Epoch 77/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0761 - accuracy: 0.9672 - val_loss: 0.1110 - val_accuracy: 0.9583
# Epoch 78/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9664 - val_loss: 0.1289 - val_accuracy: 0.9400
# Epoch 79/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9671 - val_loss: 0.1076 - val_accuracy: 0.9648
# Epoch 80/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 0.9671 - val_loss: 0.1029 - val_accuracy: 0.9635
# Epoch 81/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9662 - val_loss: 0.1022 - val_accuracy: 0.9648
# Epoch 82/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9680 - val_loss: 0.1096 - val_accuracy: 0.9622
# Epoch 83/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9671 - val_loss: 0.1091 - val_accuracy: 0.9583
# Epoch 84/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9672 - val_loss: 0.0977 - val_accuracy: 0.9687
# Epoch 85/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0736 - accuracy: 0.9674 - val_loss: 0.0984 - val_accuracy: 0.9687
# Epoch 86/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9664 - val_loss: 0.1149 - val_accuracy: 0.9570
# Epoch 87/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9664 - val_loss: 0.1044 - val_accuracy: 0.9635
# Epoch 88/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9677 - val_loss: 0.1098 - val_accuracy: 0.9622
# Epoch 89/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 0.9674 - val_loss: 0.1065 - val_accuracy: 0.9622
# Epoch 90/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9675 - val_loss: 0.1123 - val_accuracy: 0.9596
# Epoch 91/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9675 - val_loss: 0.1082 - val_accuracy: 0.9622
# Epoch 92/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9669 - val_loss: 0.1050 - val_accuracy: 0.9635
# Epoch 93/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9677 - val_loss: 0.1067 - val_accuracy: 0.9609
# Epoch 94/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9665 - val_loss: 0.1046 - val_accuracy: 0.9635
# Epoch 95/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9667 - val_loss: 0.1130 - val_accuracy: 0.9570
# Epoch 96/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9672 - val_loss: 0.1041 - val_accuracy: 0.9635
# Epoch 97/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9674 - val_loss: 0.1165 - val_accuracy: 0.9570
# Epoch 98/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9674 - val_loss: 0.1180 - val_accuracy: 0.9544
# Epoch 99/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9671 - val_loss: 0.1165 - val_accuracy: 0.9557
# Epoch 100/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9675 - val_loss: 0.1077 - val_accuracy: 0.9635

# %%
p = []
peri = []
s_index = []

for i in tqdm(np.arange(0,40,10)):

    plt.figure(figsize=(15,6))
    sleep(3)
    data_to_test = data.sel(time=slice(str(1970+i),str(1990+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    #pc_test = (pc_test)/pc_test.max(axis=0)
    pred_season = lstm_net.predict(pc_test, verbose = 0)
    p.append(pred_season)

    for i in range(n_seas):

        plt.plot(range(0,len(pred_season)),pred_season[:,i], label=f'{seasons_names[i]}')
    
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
    plt.grid()
    plt.legend()
    plt.ylabel('prob')
    plt.title(f"{data_to_test['time.year'][0].to_numpy()} - {data_to_test['time.year'][-1].to_numpy()}")
    
    plt.figure(figsize=(15,6))
    data_to_test_doy.tp.mean(['lat','lon']).plot()
    plt.grid()

    s_index.append(pred_season.argmax(-1))
# Out:
# 100%|██████████| 4/4 [00:16<00:00,  4.16s/it]

# %%
fig, ax = plt.subplots(2,1, figsize=(15,12))

for j in range(len(peri)):

    ax[0].plot(range(0,len(pred_season)),p[j][:,0])
    ax[0].set_title(f'{seasons_names[0]}')
    ax[1].plot(range(0,len(pred_season)),p[j][:,1], label = f'{peri[j][0]} - {peri[j][1]}')
    ax[1].set_title(f'{seasons_names[1]}')


for i in ax:
    i.set_ylabel('prob')
    i.grid()
    i.set_xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])



fig.legend(loc = 'center right')

# %%
p = []
peri = []
s_index = []
s_len = []
s_mean = []

for i in tqdm(np.arange(0,50,1)):

    sleep(3)
    data_to_test = data.sel(time=slice(str(1950+i),str(1970+i)))
    data_to_test_doy = data_to_test.groupby('time.dayofyear').mean()

    l_t = data_to_test_doy.mean(['lat','lon']).tp.to_numpy()
    l_t = l_t[0:365]

    peri.append([data_to_test['time.year'][0].to_numpy() , data_to_test['time.year'][-1].to_numpy()])

    to_eof = []
    for i in fields:
        supp = getattr(data_to_test_doy,i)
        supp = (supp-supp.mean())/supp.std()
        to_eof.append(supp.to_numpy())


    pc_test = solver.projectField(to_eof)
    pc_test = pc_test[:,0:n_eof_comp]
    pc_test = pc_test[0:365]
    pred_season = lstm_net.predict(pc_test, verbose=0)
    p.append(pred_season)

    predi = pred_season.argmax(-1)
    
    s_index.append(predi)

    len_seas = np.empty((n_seas,1))
    mean_seas = np.empty((n_seas,1))

    for k in range(n_seas):
        len_seas[k] = np.count_nonzero(predi==k)
        mean_seas[k] = np.mean(l_t[predi==k])

    s_len.append(len_seas)
    s_mean.append(mean_seas)
# Out:
# 100%|██████████| 50/50 [03:15<00:00,  3.91s/it]

# %%
s_len = np.array(s_len)
s_mean = np.array(s_mean)

plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_len[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season length')


plt.figure(figsize=(15,6))
for j in range(n_seas):

        plt.plot(s_mean[:,j], '-*', label = seasons_names[j])

plt.legend()
plt.grid()
plt.title('Season mean')
# Out:
# Text(0.5, 1.0, 'Season mean')

# %%
pr = np.squeeze(np.array(p))
plt.figure(figsize=(20,5))
ps = np.squeeze(np.array(peri))


for i in range(n_seas):
    plt.figure(figsize=(15,10))
    cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)
    plt.title(seasons_names[i])
    plt.xticks([0,31,60,91,121,152,182,213,244,274,305,335,366],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec','jan'])
# Out:
# /tmp/ipykernel_977761/2417149041.py:8: UserWarning: The following kwargs were not used by contour: 'vamx'
#   cs = plt.contourf(range(365), ps[:,0], pr[:,:,i], origin='lower', cmap='Reds',vmin=0,vamx=1.1)
